# %%
import datajoint as dj
import numpy as np
import datetime
import math
import os

#from cloudvolume import CloudVolume
#from collections import Counter
#from funconnect import ta3

# %%
#setting the address and the username
dj.config['database.host'] = '10.28.0.34'
dj.config['database.user'] = 'celiib'
dj.config['database.password'] = 'newceliipass'
dj.config['safemode']=True
dj.config["display.limit"] = 10


# user: celiib
# pass: newceliipass
# host: at-database.ad.bcm.edu
# schemas: microns_% and celiib_%

# %%
schema = dj.schema('microns_ta3p100')
ta3p100 = dj.create_virtual_module('ta3p100', 'microns_ta3p100')
# Out:
# Connecting celiib@10.28.0.34:3306

# %%
ta3p100.ComponentAutoSegmentWhole()
# Out:
# *segmentation  *segment_id    *decimation_ra *clusters    *smoothness    n_triangles    seg_group  sdf        median_sdf     mean_sdf     third_q     ninety_perc    time_updated
# +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +--------+ +--------+ +------------+ +----------+ +---------+ +------------+ +------------+
# 2              64851834634279 0.35           3            0.20           635453         =BLOB=     =BLOB=     0.04695        0.09499      0.07108     0.17120        2019-01-23 08:
# 2              64851834634280 0.35           3            0.20           498280         =BLOB=     =BLOB=     0.02948        0.11169      0.04936     0.39701        2019-01-23 08:
# 2              64851834634938 0.35           3            0.20           56682          =BLOB=     =BLOB=     0.08802        0.20500      0.20155     0.66602        2019-01-23 08:
# 2              64851834634946 0.35           3            0.20           552296         =BLOB=     =BLOB=     0.03656        0.12033      0.06777     0.31134        2019-01-23 08:
# 2              64851834634947 0.35           3            0.20           631278         =BLOB=     =BLOB=     0.02968        0.11563      0.04690     0.43327        2019-01-23 08:
# 2              64851834634947 0.35           3            0.20           587270         =BLOB=     =BLOB=     0.03742        0.08113      0.06768     0.22457        2019-01-23 08:
# 2              64851834634947 0.35           3            0.20           545504         =BLOB=     =BLOB=     0.05377        0.10547      0.10855     0.29034        2019-01-23 08:
# 2              64851834634947 0.35           3            0.20           899084         =BLOB=     =BLOB=     0.03857        0.09454      0.05529     0.12430        2019-01-23 08:
# 2              64851834634947 0.35           3            0.20           1429683        =BLOB=     =BLOB=     0.03176        0.07021      0.04304     0.07462        2019-01-23 08:
# 2              64851834634947 0.35           3            0.20           1408770        =BLOB=     =BLOB=     0.04444        0.07127      0.06320     0.12197        2019-01-23 08:
#    ...
#  (317 tuples)

# %%
sc
